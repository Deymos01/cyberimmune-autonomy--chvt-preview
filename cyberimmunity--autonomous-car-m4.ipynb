# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 4
#
# ## О документе
#
# Версия 1.03
#
# Модуль 4 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 4. Следование по трассе с киберпрепятствиями
#
# Для успешного выполнения этого задания необходимое активировать специальный режим работы виртуальной машинки - в рамках этого задания можно менять только блоки, отвечающие за безопасность (ограничитель, монитор безопасности), **другие блоки менять запрещено**.
#
# При прохождении маршрута будут имитироваться атаки со стороны злоумышленников, которые будут пытаться нарушить цели безопасности. Важно, чтобы им это не удалось.

# %% [markdown]
# 1. Запустите свою машинку и убедитесь, что она проходит всю трассу без нарушений ограничений скорости. При необходимости измените логику работы блока безопасности
# 2. Добавьте контроль доставки груза в модуле SafetyBlock - убедитесь, что груз доставляется до конечной точки маршрута.
# 3. Если в модуле 3 вы реализовали монитор безопасности - не забудьте его перенести в этот модуль, это принесёт дополнительные баллы!

# %% [markdown]
# Активация киберпрепятствий в системе управления:
#
# после инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# В этом блоке добавьте все ваши реализации изменённых бортовых систем

# %%
# ваш код
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import SERVOS_QUEUE_NAME, COMMUNICATION_GATEWAY_QUEUE_NAME, NAVIGATION_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME, CONTROL_SYSTEM_QUEUE_NAME, CARGO_BAY_QUEUE_NAME
from src.config import LOG_DEBUG, LOG_ERROR, LOG_INFO, LOG_FAILURE

from multiprocessing import Queue
from src.event_types import Event
from src.safety_block import BaseSafetyBlock
import math

from src.communication_gateway import BaseCommunicationGateway
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_speed'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_speed'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='release_cargo'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='release_cargo'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='position_update'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='position_update'
            ),
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(LOG_DEBUG, "событие разрешено политиками, выполняем")
            return True

        self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return False


class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        
        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут")
            self._stop_afcs()
            return
        
        if not self._route.next_point():
            self._log_message(LOG_FAILURE, "Нет следующей точки маршрута.")
            self._stop_afcs()
            return
        
        next_direction = self._calculate_direction()
        error_direction = 1

        if (abs(next_direction - direction) > error_direction):
            self._log_message(LOG_ERROR, "Внештатное изменение направления движения.")

        self._direction = next_direction
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут")
            self._stop_afcs()
            return

        allowed_speed = self._route.calculate_speed()
        if allowed_speed < speed:
            self._log_message(LOG_ERROR, f"Внештатное превышение скорости: {speed}. Разрешенная скорость: {allowed_speed}")
            self._speed = allowed_speed
        else:
            self._speed = speed
        
        self._send_speed_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека.")
        self._send_lock_cargo_to_consumers()
    
    def _release_cargo(self, _):
        if not self._route.route_finished:
            self._log_message(LOG_FAILURE, "АНТС не в конечной точке маршрута. Невозможно разблокировать грузовой отсек.")
            return
        self._send_release_cargo_to_consumers()

    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        cargo_q_name = CARGO_BAY_QUEUE_NAME
        cargo_q = self._queues_dir.get_queue(cargo_q_name)
        # инициализация сообщения с командой на блокировку грузового отсека
        event = Event(
            source=self.event_source_name,
            destination=cargo_q_name,
            operation="lock_cargo",
            parameters=None
        )
        cargo_q.put(event)
        
    
    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_INFO, "Разблокировка грузового отсека")
        cargo_q_name = CARGO_BAY_QUEUE_NAME
        cargo_q = self._queues_dir.get_queue(cargo_q_name)
        # инициализация сообщения с командой на разблокировку грузового отсека
        event = Event(
            source=self.event_source_name,
            destination=cargo_q_name,
            operation="release_cargo",
            parameters=None
        )
        cargo_q.put(event)
    
    def _stop_afcs(self):
        self._direction = 0
        self._speed = 0
        self._log_message(LOG_FAILURE, "АНТС принудительно остановлено.")
    
    def _calculate_direction(self):
        current_lattitude = math.radians(self._position.latitude)
        next_lattitude = math.radians(self._route.next_point().latitude)
        delta_longtitude = math.radians(self._route.next_point().longitude - self._position.longitude)

        x = math.sin(delta_longtitude) * math.cos(next_lattitude)
        y = math.cos(current_lattitude) * math.sin(next_lattitude) - \
            math.sin(current_lattitude) * math.cos(next_lattitude) * math.cos(delta_longtitude)

        return (math.degrees(math.atan2(x, y)) + 360) % 360


class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        
        # имена очередей блоков находятся в файле src/config.py
        # события нужно отправлять в соответствие с диаграммой информационных потоков
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # события передаются в виде экземпляров класса Event, 
        # описание класса находится в файле src/event_types.py
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )

        # поиск в каталоге нужной очереди (в данном случае - системы управления)
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        # отправка события в найденную очередь
        control_q.put(event)
        safety_q.put(safety_event)


class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        # servos_q_name = SERVOS_QUEUE_NAME
        # servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # инициализация сообщения с желаемой скоростью
        event_speed = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="set_speed",
            parameters=speed
        )

        # отправка сообщения с желаемым направлением
        event_direction = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="set_direction",
            parameters=direction
        )

        safety_q.put(event_speed)
        safety_q.put(event_direction)
    
    def _lock_cargo(self):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q = self._queues_dir.get_queue(safety_q_name)
        # инициализация сообщения с командой на блокировку грузового отсека
        event = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="lock_cargo",
            parameters=None
        )
        safety_q.put(event)

    def _release_cargo(self):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q = self._queues_dir.get_queue(safety_q_name)
        # инициализация сообщения с командой на разблокировку грузового отсека
        event = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="release_cargo",
            parameters=None
        )
        safety_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        event = Event(
            source=self.event_source_name,
            destination=control_q_name,
            operation="position_update",
            parameters=self._position
        )

        safety_event = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="position_update",
            parameters=self._position
        )

        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        control_q.put(event)
        safety_q.put(safety_event)

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m5"

# %% [markdown]
# В следующем блоке измените маршрут на ваш, его можно скопировать из модуля 2.
#
# Для проверки работы систем безопасности будут активированы киберпрепятствия
#
# ```python
# control_system.enable_critical_surprises()
# ```

# %%
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep

from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser
from src.mission_type import GeoSpecificSpeedLimit


# возьмём маршрут из модуля 2
wpl_file = "route-module4.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()

# обновите скоростные ограничения для вашего маршрута!
speed_limits = [
    GeoSpecificSpeedLimit(0, 30),
    GeoSpecificSpeedLimit(10, 40),
    GeoSpecificSpeedLimit(22, 60),
    GeoSpecificSpeedLimit(49, 30),
    GeoSpecificSpeedLimit(52, 90),
    GeoSpecificSpeedLimit(53, 40),
    GeoSpecificSpeedLimit(73, 90),
    GeoSpecificSpeedLimit(99, 40),
    GeoSpecificSpeedLimit(111, 60),
]

home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 


# создание блоков передачи данных в СУПА
if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

# создание основных функциональных блоков
mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)
security_monitor = SecurityMonitor(queues_dir=queues_dir)


# сборка всех запускаемых блоков в одном "кузове"
system_components = SystemComponentsContainer(
    components=[
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block,
        security_monitor
    ] if afcs_present else [
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block,
        security_monitor
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

# запуск всех блоков
system_components.start()

# ограничение поездки по времени
# в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# при условии, что повторный запуск закончился успешно
sleep(1000)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='communication', destination='safety', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed'), SecurityPolicy(source='safety', destination='servos', operation='set_speed'), SecurityPolicy(source='control', destination='safety', operation='set_direction'), SecurityPolicy(source='safety', destination='servos', operation='set_direction'), SecurityPolicy(source='control', destination='safety', operation='release_cargo'), SecurityPolicy(source='safety', destination='cargo', operation='release_cargo'), SecurityPolicy(source='control', destination='safety', operation='lock_cargo'), SecurityPolicy(source='safety', destination='cargo', operation='lock_cargo'), SecurityPolicy(source='navigation', destination='safety', operation='position_update'), SecurityPolicy(source='navigation', destination='control', operation='position_update')]
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][SECURITY] старт блока грузового отсека
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 17:34:21.578348
# [ИНФО][SAFETY] Блокировка грузового отсека.
# [ИНФО][SAFETY] Блокировка грузового отсека
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][CONTROL] новая скорость 30 (была 0)
# [ИНФО][CONTROL] новое направление 194 (было 0)
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.7012s N, 30 16m 22.1988s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.7012s N, 30 16m 22.1988s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.7012s N, 30 16m 22.1988s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.5709s N, 30 16m 22.1318s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.4405s N, 30 16m 22.0647s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.3102s N, 30 16m 21.9977s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.1799s N, 30 16m 21.9307s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.0495s N, 30 16m 21.8637s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.9192s N, 30 16m 21.7966s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.7889s N, 30 16m 21.7296s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.6585s N, 30 16m 21.6625s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.5543s N, 30 16m 21.6089s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.4239s N, 30 16m 21.5418s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.2936s N, 30 16m 21.4748s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.1633s N, 30 16m 21.4077s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.033s N, 30 16m 21.3406s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 48.9026s N, 30 16m 21.2736s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 48.7723s N, 30 16m 21.2065s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 48.642s N, 30 16m 21.1394s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 48.5117s N, 30 16m 21.0723s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 48.3813s N, 30 16m 21.0052s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 48.251s N, 30 16m 20.9381s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 48.1207s N, 30 16m 20.871s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.9904s N, 30 16m 20.8038s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.86s N, 30 16m 20.7367s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.7297s N, 30 16m 20.6695s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.5994s N, 30 16m 20.6024s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.4691s N, 30 16m 20.5352s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.3388s N, 30 16m 20.468s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.2085s N, 30 16m 20.4007s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.0782s N, 30 16m 20.3335s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.9479s N, 30 16m 20.2662s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 322 (было 194)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.8176s N, 30 16m 20.1989s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][CONTROL] новое направление 320 (было 322)
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.6873s N, 30 16m 20.1314s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][CONTROL] новое направление 319 (было 320)
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.557s N, 30 16m 20.0638s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][CONTROL] новое направление 318 (было 319)
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.4505s N, 30 16m 20.2271s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.3462s N, 30 16m 20.3962s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.2446s N, 30 16m 20.5714s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.1431s N, 30 16m 20.7469s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.0417s N, 30 16m 20.9228s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.9606s N, 30 16m 21.0635s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.8593s N, 30 16m 21.2394s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.7579s N, 30 16m 21.4153s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.6566s N, 30 16m 21.5912s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.5553s N, 30 16m 21.7671s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.4539s N, 30 16m 21.943s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.3526s N, 30 16m 22.1189s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.2513s N, 30 16m 22.2949s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.1499s N, 30 16m 22.4708s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.0486s N, 30 16m 22.6468s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.9473s N, 30 16m 22.8227s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.846s N, 30 16m 22.9987s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.7447s N, 30 16m 23.1747s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.6434s N, 30 16m 23.3508s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.5422s N, 30 16m 23.5268s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.4409s N, 30 16m 23.7029s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.3396s N, 30 16m 23.879s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.2384s N, 30 16m 24.0551s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.1372s N, 30 16m 24.2312s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.0359s N, 30 16m 24.4074s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.9347s N, 30 16m 24.5836s E
# [ОШИБКА][SAFETY] Внештатное изменение направления движения.
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 130 (была 30)
# [ИНФО][CONTROL] новое направление 82 (было 318)
# [ИНФО][SAFETY] сегмент пройден
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.8336s N, 30 16m 24.7599s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.7325s N, 30 16m 24.9363s E
# [ИНФО][CONTROL] новое направление 81 (было 82)
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.6314s N, 30 16m 25.1129s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.649s N, 30 16m 25.3778s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.6676s N, 30 16m 25.6424s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.6873s N, 30 16m 25.9067s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.7069s N, 30 16m 26.1711s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.7265s N, 30 16m 26.4354s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.7422s N, 30 16m 26.6468s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.7619s N, 30 16m 26.9111s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.7815s N, 30 16m 27.1754s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.8012s N, 30 16m 27.4398s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.8208s N, 30 16m 27.7041s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.8404s N, 30 16m 27.9684s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.8601s N, 30 16m 28.2327s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.8797s N, 30 16m 28.497s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.8993s N, 30 16m 28.7613s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.919s N, 30 16m 29.0256s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.9386s N, 30 16m 29.2899s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.9582s N, 30 16m 29.5543s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.9779s N, 30 16m 29.8186s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.9975s N, 30 16m 30.0829s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.0171s N, 30 16m 30.3472s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.0368s N, 30 16m 30.6115s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.0564s N, 30 16m 30.8758s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.076s N, 30 16m 31.1402s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.0957s N, 30 16m 31.4045s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.1153s N, 30 16m 31.6688s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.1349s N, 30 16m 31.9331s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.1546s N, 30 16m 32.1974s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.1742s N, 30 16m 32.4617s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.1938s N, 30 16m 32.726s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.2134s N, 30 16m 32.9904s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.2331s N, 30 16m 33.2547s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.2527s N, 30 16m 33.519s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.2723s N, 30 16m 33.7833s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.288s N, 30 16m 33.9948s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.3077s N, 30 16m 34.2591s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.3273s N, 30 16m 34.5234s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.3469s N, 30 16m 34.7877s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.3665s N, 30 16m 35.052s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.3861s N, 30 16m 35.3164s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.4058s N, 30 16m 35.5807s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.4254s N, 30 16m 35.845s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.445s N, 30 16m 36.1093s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.4646s N, 30 16m 36.3736s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.4843s N, 30 16m 36.638s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.5039s N, 30 16m 36.9023s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.5235s N, 30 16m 37.1666s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.5431s N, 30 16m 37.4309s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.5627s N, 30 16m 37.6952s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.5823s N, 30 16m 37.9596s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.602s N, 30 16m 38.2239s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.6216s N, 30 16m 38.4882s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.6412s N, 30 16m 38.7525s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.6608s N, 30 16m 39.0168s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.6804s N, 30 16m 39.2812s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.7s N, 30 16m 39.5455s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.7196s N, 30 16m 39.8098s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.7392s N, 30 16m 40.0741s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.7589s N, 30 16m 40.3385s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.7785s N, 30 16m 40.6028s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.7981s N, 30 16m 40.8671s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.8138s N, 30 16m 41.0786s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.8334s N, 30 16m 41.3429s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.853s N, 30 16m 41.6072s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.8726s N, 30 16m 41.8715s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.8922s N, 30 16m 42.1359s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.9118s N, 30 16m 42.4002s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.9314s N, 30 16m 42.6645s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.951s N, 30 16m 42.9288s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.9706s N, 30 16m 43.1932s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.9902s N, 30 16m 43.4575s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.0098s N, 30 16m 43.7218s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.0294s N, 30 16m 43.9861s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.049s N, 30 16m 44.2505s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.0686s N, 30 16m 44.5148s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.0882s N, 30 16m 44.7791s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.1078s N, 30 16m 45.0435s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.1274s N, 30 16m 45.3078s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.147s N, 30 16m 45.5721s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.1665s N, 30 16m 45.8364s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.1861s N, 30 16m 46.1008s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.2057s N, 30 16m 46.3651s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.2253s N, 30 16m 46.6294s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.2449s N, 30 16m 46.8938s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.2645s N, 30 16m 47.1581s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.2841s N, 30 16m 47.4224s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.3036s N, 30 16m 47.6868s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.3232s N, 30 16m 47.9511s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.3428s N, 30 16m 48.2154s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.3624s N, 30 16m 48.4798s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.378s N, 30 16m 48.6912s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.3976s N, 30 16m 48.9556s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.4172s N, 30 16m 49.2199s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.4367s N, 30 16m 49.4842s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.4563s N, 30 16m 49.7486s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.4759s N, 30 16m 50.0129s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.4954s N, 30 16m 50.2773s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.515s N, 30 16m 50.5416s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.5346s N, 30 16m 50.8059s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.5541s N, 30 16m 51.0703s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.5737s N, 30 16m 51.3346s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.5932s N, 30 16m 51.599s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.6128s N, 30 16m 51.8633s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.6323s N, 30 16m 52.1276s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.6519s N, 30 16m 52.392s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.6714s N, 30 16m 52.6563s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.6909s N, 30 16m 52.9207s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.7105s N, 30 16m 53.185s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.73s N, 30 16m 53.4494s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.7495s N, 30 16m 53.7137s E
# [ОШИБКА][SAFETY] Внештатное превышение скорости: 130. Разрешенная скорость: 30
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.769s N, 30 16m 53.9781s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 30 (была 130)
# [ИНФО][CONTROL] новое направление 106 (было 81)
# [ИНФО][SAFETY] сегмент пройден
# [ОТКАЗ][SAFETY] АНТС не в конечной точке маршрута. Невозможно разблокировать грузовой отсек.
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.7885s N, 30 16m 54.2425s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.8079s N, 30 16m 54.5068s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.8273s N, 30 16m 54.7712s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.7899s N, 30 16m 55.0279s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.7522s N, 30 16m 55.2844s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.7144s N, 30 16m 55.5408s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.6766s N, 30 16m 55.7972s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.6388s N, 30 16m 56.0536s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.6009s N, 30 16m 56.31s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.5707s N, 30 16m 56.5152s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.5328s N, 30 16m 56.7716s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.495s N, 30 16m 57.028s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.4572s N, 30 16m 57.2844s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.4194s N, 30 16m 57.5408s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.3815s N, 30 16m 57.7972s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.3437s N, 30 16m 58.0536s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.3059s N, 30 16m 58.3101s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.268s N, 30 16m 58.5665s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.2302s N, 30 16m 58.8229s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.1924s N, 30 16m 59.0793s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.1546s N, 30 16m 59.3357s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.1167s N, 30 16m 59.5921s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.0789s N, 30 16m 59.8485s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.0411s N, 30 17m 0.10493s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.0032s N, 30 17m 0.361341s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.9654s N, 30 17m 0.617753s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.9276s N, 30 17m 0.874164s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.8898s N, 30 17m 1.13058s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.8519s N, 30 17m 1.38699s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.8141s N, 30 17m 1.6434s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.7763s N, 30 17m 1.89981s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.7385s N, 30 17m 2.15622s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.7006s N, 30 17m 2.41263s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.6628s N, 30 17m 2.66904s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.625s N, 30 17m 2.92545s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.5872s N, 30 17m 3.18186s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.5493s N, 30 17m 3.43828s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.5115s N, 30 17m 3.69469s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.4737s N, 30 17m 3.9511s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.4358s N, 30 17m 4.20751s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.398s N, 30 17m 4.46392s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.3602s N, 30 17m 4.72033s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.3299s N, 30 17m 4.92546s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.2921s N, 30 17m 5.18187s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.2543s N, 30 17m 5.43828s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.2165s N, 30 17m 5.69469s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.1786s N, 30 17m 5.9511s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.1408s N, 30 17m 6.20751s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.103s N, 30 17m 6.46392s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.0652s N, 30 17m 6.72034s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.0273s N, 30 17m 6.97675s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.9895s N, 30 17m 7.23316s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.9517s N, 30 17m 7.48957s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.9139s N, 30 17m 7.74598s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.876s N, 30 17m 8.00239s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.8382s N, 30 17m 8.2588s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.8004s N, 30 17m 8.51521s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.7626s N, 30 17m 8.77162s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.7247s N, 30 17m 9.02803s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.6869s N, 30 17m 9.28444s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.6491s N, 30 17m 9.54085s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.6113s N, 30 17m 9.79726s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.5734s N, 30 17m 10.0537s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.5356s N, 30 17m 10.3101s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.4978s N, 30 17m 10.5665s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.46s N, 30 17m 10.8229s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.4222s N, 30 17m 11.0793s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.3843s N, 30 17m 11.3357s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.3465s N, 30 17m 11.5921s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.3087s N, 30 17m 11.8486s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.2709s N, 30 17m 12.105s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.233s N, 30 17m 12.3614s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.2028s N, 30 17m 12.5665s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.165s N, 30 17m 12.8229s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.1271s N, 30 17m 13.0793s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.0893s N, 30 17m 13.3357s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.0515s N, 30 17m 13.5921s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.0137s N, 30 17m 13.8486s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.9759s N, 30 17m 14.105s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.938s N, 30 17m 14.3614s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.9002s N, 30 17m 14.6178s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.8624s N, 30 17m 14.8742s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.8246s N, 30 17m 15.1306s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.7868s N, 30 17m 15.387s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.7489s N, 30 17m 15.6434s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.7111s N, 30 17m 15.8998s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.6733s N, 30 17m 16.1563s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.6355s N, 30 17m 16.4127s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.5977s N, 30 17m 16.6691s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.5598s N, 30 17m 16.9255s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.522s N, 30 17m 17.1819s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.4842s N, 30 17m 17.4383s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.4464s N, 30 17m 17.6947s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.4086s N, 30 17m 17.9511s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.3707s N, 30 17m 18.2075s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.3329s N, 30 17m 18.464s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.2951s N, 30 17m 18.7204s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.2573s N, 30 17m 18.9768s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.2195s N, 30 17m 19.2332s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.1817s N, 30 17m 19.4896s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.1438s N, 30 17m 19.746s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.106s N, 30 17m 20.0024s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.0758s N, 30 17m 20.2076s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.038s N, 30 17m 20.464s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 42.0001s N, 30 17m 20.7204s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.9623s N, 30 17m 20.9768s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.9245s N, 30 17m 21.2332s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.8867s N, 30 17m 21.4896s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.8489s N, 30 17m 21.746s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.8111s N, 30 17m 22.0024s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.7732s N, 30 17m 22.2588s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.7354s N, 30 17m 22.5153s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.6976s N, 30 17m 22.7717s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.6598s N, 30 17m 23.0281s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.622s N, 30 17m 23.2845s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.5842s N, 30 17m 23.5409s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.5464s N, 30 17m 23.7973s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.5085s N, 30 17m 24.0537s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.4707s N, 30 17m 24.3101s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.4329s N, 30 17m 24.5666s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.3951s N, 30 17m 24.823s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.3573s N, 30 17m 25.0794s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.3195s N, 30 17m 25.3358s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.2817s N, 30 17m 25.5922s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.2439s N, 30 17m 25.8486s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.2061s N, 30 17m 26.105s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.1682s N, 30 17m 26.3614s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.1304s N, 30 17m 26.6179s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.0926s N, 30 17m 26.8743s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.0548s N, 30 17m 27.1307s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 41.017s N, 30 17m 27.3871s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.9868s N, 30 17m 27.5922s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.9489s N, 30 17m 27.8486s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.9111s N, 30 17m 28.105s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.8733s N, 30 17m 28.3615s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.8355s N, 30 17m 28.6179s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.7977s N, 30 17m 28.8743s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.7599s N, 30 17m 29.1307s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.7221s N, 30 17m 29.3871s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.6843s N, 30 17m 29.6435s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.6465s N, 30 17m 29.8999s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.6087s N, 30 17m 30.1564s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.5709s N, 30 17m 30.4128s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.5331s N, 30 17m 30.6692s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.4952s N, 30 17m 30.9256s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.4574s N, 30 17m 31.182s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.4196s N, 30 17m 31.4384s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.3818s N, 30 17m 31.6948s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.344s N, 30 17m 31.9513s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.3062s N, 30 17m 32.2077s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.2684s N, 30 17m 32.4641s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.2306s N, 30 17m 32.7205s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.1928s N, 30 17m 32.9769s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.155s N, 30 17m 33.2333s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.1172s N, 30 17m 33.4897s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.0794s N, 30 17m 33.7462s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.0416s N, 30 17m 34.0026s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 40.0038s N, 30 17m 34.259s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.966s N, 30 17m 34.5154s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.9282s N, 30 17m 34.7718s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.8904s N, 30 17m 35.0282s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.8526s N, 30 17m 35.2847s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.8223s N, 30 17m 35.4898s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.7845s N, 30 17m 35.7462s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.7467s N, 30 17m 36.0026s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.709s N, 30 17m 36.259s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.6712s N, 30 17m 36.5155s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.6334s N, 30 17m 36.7719s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.5956s N, 30 17m 37.0283s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.5578s N, 30 17m 37.2847s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.52s N, 30 17m 37.5411s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.4822s N, 30 17m 37.7975s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.4444s N, 30 17m 38.054s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.4066s N, 30 17m 38.3104s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.3688s N, 30 17m 38.5668s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.331s N, 30 17m 38.8232s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.2932s N, 30 17m 39.0796s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.2554s N, 30 17m 39.336s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.2176s N, 30 17m 39.5925s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.1798s N, 30 17m 39.8489s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.142s N, 30 17m 40.1053s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.1042s N, 30 17m 40.3617s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.0664s N, 30 17m 40.6181s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 39.0286s N, 30 17m 40.8746s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.9908s N, 30 17m 41.131s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.9531s N, 30 17m 41.3874s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.9153s N, 30 17m 41.6438s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.8775s N, 30 17m 41.9002s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.8397s N, 30 17m 42.1567s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.8019s N, 30 17m 42.4131s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.7717s N, 30 17m 42.6182s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.7339s N, 30 17m 42.8746s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.6961s N, 30 17m 43.1311s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.6583s N, 30 17m 43.3875s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.6205s N, 30 17m 43.6439s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.5827s N, 30 17m 43.9003s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.545s N, 30 17m 44.1568s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.5072s N, 30 17m 44.4132s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.4694s N, 30 17m 44.6696s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.4316s N, 30 17m 44.926s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.3938s N, 30 17m 45.1824s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.356s N, 30 17m 45.4389s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.3183s N, 30 17m 45.6953s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.2805s N, 30 17m 45.9517s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.2427s N, 30 17m 46.2081s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.2049s N, 30 17m 46.4646s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.1671s N, 30 17m 46.721s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.1294s N, 30 17m 46.9774s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.0916s N, 30 17m 47.2338s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.0538s N, 30 17m 47.4903s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 38.016s N, 30 17m 47.7467s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.9783s N, 30 17m 48.0031s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.9405s N, 30 17m 48.2596s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.9027s N, 30 17m 48.516s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.865s N, 30 17m 48.7724s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.8272s N, 30 17m 49.0288s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.7894s N, 30 17m 49.2853s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.7516s N, 30 17m 49.5417s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.7139s N, 30 17m 49.7981s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.6761s N, 30 17m 50.0546s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.6383s N, 30 17m 50.311s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.6006s N, 30 17m 50.5674s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.5628s N, 30 17m 50.8239s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.5326s N, 30 17m 51.029s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.4948s N, 30 17m 51.2854s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.4571s N, 30 17m 51.5419s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.4193s N, 30 17m 51.7983s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.3816s N, 30 17m 52.0547s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.3438s N, 30 17m 52.3112s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.306s N, 30 17m 52.5676s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.2683s N, 30 17m 52.824s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.2305s N, 30 17m 53.0805s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.1928s N, 30 17m 53.3369s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.155s N, 30 17m 53.5934s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.1173s N, 30 17m 53.8498s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.0795s N, 30 17m 54.1062s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.0418s N, 30 17m 54.3627s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 37.004s N, 30 17m 54.6191s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.9663s N, 30 17m 54.8755s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.9285s N, 30 17m 55.132s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.8908s N, 30 17m 55.3884s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.853s N, 30 17m 55.6449s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.8153s N, 30 17m 55.9013s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.7776s N, 30 17m 56.1578s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.7398s N, 30 17m 56.4142s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.7021s N, 30 17m 56.6707s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.6643s N, 30 17m 56.9271s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.6266s N, 30 17m 57.1836s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.5889s N, 30 17m 57.44s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.5511s N, 30 17m 57.6965s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.5134s N, 30 17m 57.9529s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.4757s N, 30 17m 58.2094s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.4455s N, 30 17m 58.4145s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.4078s N, 30 17m 58.671s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.3701s N, 30 17m 58.9274s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.3324s N, 30 17m 59.1839s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.2946s N, 30 17m 59.4403s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.2569s N, 30 17m 59.6968s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.2192s N, 30 17m 59.9533s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.1815s N, 30 18m 0.20973s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.1438s N, 30 18m 0.466195s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.1061s N, 30 18m 0.722662s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.0684s N, 30 18m 0.97913s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 36.0307s N, 30 18m 1.2356s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.993s N, 30 18m 1.49207s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.9554s N, 30 18m 1.74855s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.9177s N, 30 18m 2.00502s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.88s N, 30 18m 2.2615s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.8423s N, 30 18m 2.51798s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.8047s N, 30 18m 2.77447s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.767s N, 30 18m 3.03095s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.7293s N, 30 18m 3.28745s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.6917s N, 30 18m 3.54394s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.6541s N, 30 18m 3.80045s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.6164s N, 30 18m 4.05696s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.5788s N, 30 18m 4.31348s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.5413s N, 30 18m 4.57002s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.5037s N, 30 18m 4.82657s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.4662s N, 30 18m 5.08315s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.4288s N, 30 18m 5.33978s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.399s N, 30 18m 5.54515s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.3617s N, 30 18m 5.80185s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.3244s N, 30 18m 6.05856s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.2871s N, 30 18m 6.31527s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.2499s N, 30 18m 6.57198s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.2126s N, 30 18m 6.82869s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.1753s N, 30 18m 7.0854s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.138s N, 30 18m 7.3421s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.1008s N, 30 18m 7.59881s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.0635s N, 30 18m 7.85552s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 35.0262s N, 30 18m 8.11223s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 34.9889s N, 30 18m 8.36894s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 34.9517s N, 30 18m 8.62565s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 34.9144s N, 30 18m 8.88235s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 34.8771s N, 30 18m 9.13906s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 34.8398s N, 30 18m 9.39577s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 34.8026s N, 30 18m 9.65248s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 34.7653s N, 30 18m 9.90919s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 34.728s N, 30 18m 10.1659s E
# ...
# [ИНФО][SAFETY] текущие координаты: 59 49m 8.54213s N, 30 22m 50.9081s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 8.8037s N, 30 22m 50.7811s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 9.06527s N, 30 22m 50.6541s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 9.32685s N, 30 22m 50.5271s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 9.58842s N, 30 22m 50.4001s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 9.84999s N, 30 22m 50.2731s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 10.1116s N, 30 22m 50.1461s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 10.3731s N, 30 22m 50.0191s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 10.6347s N, 30 22m 49.892s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 10.8963s N, 30 22m 49.765s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 11.1578s N, 30 22m 49.638s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 11.3671s N, 30 22m 49.5364s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 11.6287s N, 30 22m 49.4094s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 11.8902s N, 30 22m 49.2823s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 12.1518s N, 30 22m 49.1553s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 12.4134s N, 30 22m 49.0282s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 12.6749s N, 30 22m 48.9012s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 12.9365s N, 30 22m 48.7741s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 13.1981s N, 30 22m 48.6471s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 13.4596s N, 30 22m 48.52s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 13.7212s N, 30 22m 48.3929s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 13.9828s N, 30 22m 48.2659s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 14.2443s N, 30 22m 48.1388s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 14.5059s N, 30 22m 48.0117s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 14.7675s N, 30 22m 47.8846s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 15.029s N, 30 22m 47.7575s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 15.2906s N, 30 22m 47.6304s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 15.5521s N, 30 22m 47.5033s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 15.8137s N, 30 22m 47.3762s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 16.0753s N, 30 22m 47.2491s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 16.3368s N, 30 22m 47.122s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 16.5984s N, 30 22m 46.9948s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 16.8599s N, 30 22m 46.8677s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 17.1215s N, 30 22m 46.7406s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 17.383s N, 30 22m 46.6134s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 17.6446s N, 30 22m 46.4862s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 17.9061s N, 30 22m 46.3591s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 18.1677s N, 30 22m 46.2319s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 18.4292s N, 30 22m 46.1047s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 18.6908s N, 30 22m 45.9776s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 18.9s N, 30 22m 45.8758s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 19.1616s N, 30 22m 45.7486s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 19.4231s N, 30 22m 45.6214s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 19.6847s N, 30 22m 45.4942s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 19.9462s N, 30 22m 45.3669s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 20.2078s N, 30 22m 45.2397s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 20.4693s N, 30 22m 45.1125s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 20.7309s N, 30 22m 44.9852s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 20.9924s N, 30 22m 44.8579s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 21.2539s N, 30 22m 44.7306s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 21.5155s N, 30 22m 44.6033s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 21.777s N, 30 22m 44.476s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 22.0385s N, 30 22m 44.3487s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 22.3001s N, 30 22m 44.2214s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 22.5616s N, 30 22m 44.094s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 22.8231s N, 30 22m 43.9667s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 23.0847s N, 30 22m 43.8393s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 23.3462s N, 30 22m 43.7119s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 23.6077s N, 30 22m 43.5844s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 23.8692s N, 30 22m 43.457s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 24.1307s N, 30 22m 43.3295s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 24.3922s N, 30 22m 43.202s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 24.6538s N, 30 22m 43.0744s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 24.9153s N, 30 22m 42.9468s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 25.1767s N, 30 22m 42.8192s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 25.4382s N, 30 22m 42.6914s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 338 (было 346)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 49m 25.6997s N, 30 22m 42.5636s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 25.9611s N, 30 22m 42.4355s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 26.2204s N, 30 22m 42.2939s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 26.4712s N, 30 22m 42.0992s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 26.7218s N, 30 22m 41.9034s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 26.9221s N, 30 22m 41.7461s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 27.1726s N, 30 22m 41.5495s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 27.423s N, 30 22m 41.3528s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 27.6734s N, 30 22m 41.1562s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 27.9238s N, 30 22m 40.9595s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 28.1742s N, 30 22m 40.7628s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 28.4246s N, 30 22m 40.5661s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 28.675s N, 30 22m 40.3694s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 28.9254s N, 30 22m 40.1727s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 29.1758s N, 30 22m 39.976s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 29.4262s N, 30 22m 39.7793s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 29.6766s N, 30 22m 39.5826s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 29.927s N, 30 22m 39.3859s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 30.1774s N, 30 22m 39.1891s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 30.4278s N, 30 22m 38.9924s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 30.6782s N, 30 22m 38.7956s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 30.9286s N, 30 22m 38.5988s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 31.179s N, 30 22m 38.4021s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 31.4293s N, 30 22m 38.2053s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 31.6797s N, 30 22m 38.0085s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 31.9301s N, 30 22m 37.8117s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 32.1805s N, 30 22m 37.6149s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 32.4309s N, 30 22m 37.4181s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 32.6813s N, 30 22m 37.2213s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 32.9316s N, 30 22m 37.0244s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 33.182s N, 30 22m 36.8276s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 33.4324s N, 30 22m 36.6307s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 33.6327s N, 30 22m 36.4732s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 33.883s N, 30 22m 36.2763s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 34.1334s N, 30 22m 36.0794s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 34.3838s N, 30 22m 35.8825s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 34.6341s N, 30 22m 35.6856s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 34.8845s N, 30 22m 35.4887s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 35.1349s N, 30 22m 35.2917s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 35.3852s N, 30 22m 35.0948s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 35.6356s N, 30 22m 34.8978s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 35.8859s N, 30 22m 34.7008s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 36.1362s N, 30 22m 34.5038s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 36.3866s N, 30 22m 34.3067s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 36.6369s N, 30 22m 34.1097s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 36.8872s N, 30 22m 33.9126s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 37.1376s N, 30 22m 33.7155s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 37.3879s N, 30 22m 33.5183s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 37.6382s N, 30 22m 33.3212s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 37.8885s N, 30 22m 33.124s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 38.1388s N, 30 22m 32.9268s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 38.3891s N, 30 22m 32.7295s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 38.6394s N, 30 22m 32.5322s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 38.8897s N, 30 22m 32.3348s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 39.1399s N, 30 22m 32.1374s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 39.3902s N, 30 22m 31.9399s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 39.6404s N, 30 22m 31.7421s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 344 (было 338)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 49m 39.8905s N, 30 22m 31.5442s E
# [ИНФО][CONTROL] новое направление 345 (было 344)
# [ИНФО][SAFETY] текущие координаты: 59 49m 40.1406s N, 30 22m 31.3458s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 40.3925s N, 30 22m 31.1587s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 40.6005s N, 30 22m 31.0471s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 40.8608s N, 30 22m 30.9103s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 41.1213s N, 30 22m 30.775s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 41.3819s N, 30 22m 30.6399s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 41.6424s N, 30 22m 30.5048s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 41.903s N, 30 22m 30.3697s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 42.1635s N, 30 22m 30.2346s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 42.4241s N, 30 22m 30.0995s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 42.6846s N, 30 22m 29.9644s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 42.9451s N, 30 22m 29.8292s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 43.2057s N, 30 22m 29.6941s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 43.4662s N, 30 22m 29.5589s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 43.7268s N, 30 22m 29.4238s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 43.9873s N, 30 22m 29.2886s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 44.2478s N, 30 22m 29.1533s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 44.5084s N, 30 22m 29.0181s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 44.7689s N, 30 22m 28.8828s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 45.0294s N, 30 22m 28.7476s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 45.2899s N, 30 22m 28.6123s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 45.5504s N, 30 22m 28.4769s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 45.8109s N, 30 22m 28.3415s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 46.0714s N, 30 22m 28.2061s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 46.3319s N, 30 22m 28.0706s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 46.5924s N, 30 22m 27.9351s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 46.8529s N, 30 22m 27.7995s E
# [ИНФО][CONTROL] маршрут пройден, текущее время 17:50:39.637040
# [ИНФО][CONTROL] новая скорость 0.0 (была 60)
# [ИНФО][CONTROL] новое направление 0 (было 345)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Разблокировка грузового отсека
# [ИНФО][SAFETY] текущие координаты: 59 49m 47.1134s N, 30 22m 27.6637s E
# [ОТКАЗ][SAFETY] Нет следующей точки маршрута.
# [ОТКАЗ][SAFETY] АНТС принудительно остановлено.
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# Убедитесь, что
# 1. ваша машинка успешно прошла весь заданный маршрут
# 2. не превысила ограничения скорости
# 3. успешно доставила груз
#
# Если всё так - поздравляем, вы справились с заданием! Обязательно зафиксируйте все изменения в репозитории!

# %% [markdown]
# Мы будем признательны за обратную связь - любые комментарии, которые вы можете дать по итогам выполнения этого задания.
#
# Например,
#
# - было ли задание понятным по шкале 1..10 (1 - ничего не понятно, 10 - вопросов вообще не было, всё понятно)?
# - было ли задание интересным по шкале 1..10 (1 - скука смертная, 10 - лучшее, что вам пока встречалось на олимпиадах)?
# - что бы вы предложили изменить, чтобы сделает его более интересным?
# - по шкале 1..10 насколько сложным оно было для вас?
# - что было самым трудным в задании?
#
# Авторы наиболее развёрнутых и интересных комментариев получат особенный приз от Лаборатории Касперского!

# %% [markdown]
# Дополнительная информация о кибериммунной разработке
# - https://os.kaspersky.ru/cyber-immune-development/
# - https://github.com/sergey-sobolev/cyberimmune-systems/wiki/%D0%9A%D0%B8%D0%B1%D0%B5%D1%80%D0%B8%D0%BC%D0%BC%D1%83%D0%BD%D0%B8%D1%82%D0%B5%D1%82
# - канал в телеграм: https://t.me/learning_cyberimmunity
